# %%
import numpy as np 

from matplotlib import pyplot as plt 

def plt_pacf(data):
    x=data[:,0]
    y=data[:,1]
    plt.plot(x,y, 'o-', markersize=2, color='r')

def plt_vacf(data):
    x=data[:,0]
    y=data[:,1]   


plt.figure()
data = np.genfromtxt('md-pol-acf.dat')
print(len(data))
n=int(len(data)/2)
plt_pacf(data[0:n,:])
#plt.figure()
#data = np.genfromtxt('md-ph-dos.dat')
#plt_ph_dos(data)

plt.show()
# Out:
# 4096

# %%
thz2cm=33.305

def plt_ir_spectra(data):
    x=data[:,0]
    y=data[:,1]
    plt.plot(x*thz2cm,y, 'o-', markersize=5, color='b')
    plt.xlim([0, 900])
plt.figure()
data = np.genfromtxt('md-ir-spectra.dat')
plt_ir_spectra(data)
#plt.figure()
#data = np.genfromtxt('md-ph-dos.dat')
#plt_ph_dos(data)

plt.show()
